# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | santa rosalia
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | peterhead
# Processing Record 13 of Set 1 | pangkalanbuun
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | ulaanbaatar
# Processing Record 21 of Set 1 | povolzhskiy
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | gazojak
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | chapais
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | domoni
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | karasuyama
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | merauke
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | zhigansk
# Processing Record 39 of Set 1 | zyryanka
# Processing Record 40 of Set 1 | coihaique
# Processing Record 41 of Set 1 | rio grande
# Processing Record 42 of Set 1 | north bend
# Processing Record 43 of Set 1 | arkhara
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | yeppoon
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | pitkyaranta
# Processing Record 48 of Set 1 | taltal
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | makakilo city
# Processing Record 5 of Set 2 | wittstock
# Processing Record 6 of Set 2 | gremyachye
# City not found. Skipping...
# Processing Record 7 of Set 2 | shingu
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | fernandina beach
# Processing Record 11 of Set 2 | myitkyina
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | abu zabad
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 2 | kroya
# Processing Record 23 of Set 2 | luanda
# Processing Record 24 of Set 2 | estelle
# Processing Record 25 of Set 2 | los llanos de aridane
# Processing Record 26 of Set 2 | rocha
# Processing Record 27 of Set 2 | kamaishi
# Processing Record 28 of Set 2 | meadow lake
# Processing Record 29 of Set 2 | horta
# Processing Record 30 of Set 2 | yumen
# Processing Record 31 of Set 2 | nantucket
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | altay
# Processing Record 34 of Set 2 | labuhan
# Processing Record 35 of Set 2 | camacha
# Processing Record 36 of Set 2 | huarmey
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | yerbogachen
# Processing Record 42 of Set 2 | nishihara
# Processing Record 43 of Set 2 | abu dhabi
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | baruun-urt
# Processing Record 46 of Set 2 | ushtobe
# Processing Record 47 of Set 2 | saint-augustin
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | kysyl-syr
# Processing Record 3 of Set 3 | dali
# Processing Record 4 of Set 3 | natal
# Processing Record 5 of Set 3 | novorzhev
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | the valley
# Processing Record 9 of Set 3 | mezhdurechensk
# Processing Record 10 of Set 3 | voskresenskoye
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | kirov
# Processing Record 13 of Set 3 | kendari
# Processing Record 14 of Set 3 | brae
# Processing Record 15 of Set 3 | longyan
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | yarmouth
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | sokoni
# Processing Record 21 of Set 3 | pachino
# Processing Record 22 of Set 3 | hofn
# Processing Record 23 of Set 3 | mapiripan
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | genhe
# Processing Record 26 of Set 3 | kokopo
# Processing Record 27 of Set 3 | salalah
# Processing Record 28 of Set 3 | nouadhibou
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | olga
# Processing Record 31 of Set 3 | klaksvik
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | jacareacanga
# Processing Record 35 of Set 3 | siguiri
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | ambovombe
# Processing Record 38 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 3 | kimbe
# Processing Record 40 of Set 3 | saint-jovite
# Processing Record 41 of Set 3 | rassvet
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 3 | ngama
# Processing Record 45 of Set 3 | sao gabriel da cachoeira
# Processing Record 46 of Set 3 | seoul
# Processing Record 47 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 3 | santa cruz de la palma
# Processing Record 49 of Set 3 | ulladulla
# Processing Record 50 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 4 | mandalgovi
# Processing Record 2 of Set 4 | omsukchan
# Processing Record 3 of Set 4 | powell
# Processing Record 4 of Set 4 | hervey bay
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | krasnotorka
# Processing Record 7 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | omboue
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | sola
# Processing Record 11 of Set 4 | codrington
# Processing Record 12 of Set 4 | morgan city
# Processing Record 13 of Set 4 | broken hill
# Processing Record 14 of Set 4 | asosa
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | pinega
# Processing Record 17 of Set 4 | vila
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | nabire
# Processing Record 21 of Set 4 | ornskoldsvik
# Processing Record 22 of Set 4 | smithers
# Processing Record 23 of Set 4 | trofors
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | bryan
# Processing Record 26 of Set 4 | palu
# Processing Record 27 of Set 4 | foso
# Processing Record 28 of Set 4 | rockland
# Processing Record 29 of Set 4 | wellington
# Processing Record 30 of Set 4 | san patricio
# Processing Record 31 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | swift current
# Processing Record 34 of Set 4 | arlit
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | launceston
# Processing Record 37 of Set 4 | chimore
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | liaozhong
# Processing Record 40 of Set 4 | okhotsk
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | gobabis
# Processing Record 44 of Set 4 | chapayevka
# Processing Record 45 of Set 4 | kangaatsiaq
# Processing Record 46 of Set 4 | kabinda
# Processing Record 47 of Set 4 | searcy
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | penhold
# Processing Record 50 of Set 4 | katherine
# Processing Record 1 of Set 5 | sisimiut
# Processing Record 2 of Set 5 | khaniotis
# Processing Record 3 of Set 5 | loanda
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | gambettola
# Processing Record 7 of Set 5 | asau
# Processing Record 8 of Set 5 | escarcega
# Processing Record 9 of Set 5 | jasper
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | valparaiso
# Processing Record 12 of Set 5 | araouane
# Processing Record 13 of Set 5 | price
# Processing Record 14 of Set 5 | polovinnoye
# Processing Record 15 of Set 5 | mecca
# Processing Record 16 of Set 5 | chicla
# Processing Record 17 of Set 5 | sri aman
# Processing Record 18 of Set 5 | awjilah
# Processing Record 19 of Set 5 | moindou
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | nelson bay
# Processing Record 22 of Set 5 | manokwari
# Processing Record 23 of Set 5 | havelock
# Processing Record 24 of Set 5 | guarapari
# Processing Record 25 of Set 5 | chuy
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | aldan
# Processing Record 28 of Set 5 | dongsheng
# Processing Record 29 of Set 5 | rawson
# Processing Record 30 of Set 5 | atambua
# Processing Record 31 of Set 5 | sarangani
# Processing Record 32 of Set 5 | grindavik
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | rauma
# Processing Record 35 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 5 | korla
# Processing Record 37 of Set 5 | macaubas
# Processing Record 38 of Set 5 | verkhoyansk
# Processing Record 39 of Set 5 | lucapa
# Processing Record 40 of Set 5 | sarab
# Processing Record 41 of Set 5 | maraa
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | nome
# Processing Record 45 of Set 5 | samarkand
# Processing Record 46 of Set 5 | porto belo
# Processing Record 47 of Set 5 | talcahuano
# Processing Record 48 of Set 5 | dawson creek
# Processing Record 49 of Set 5 | sumbawanga
# Processing Record 50 of Set 5 | cananea
# Processing Record 1 of Set 6 | buctzotz
# Processing Record 2 of Set 6 | valparai
# Processing Record 3 of Set 6 | tabou
# Processing Record 4 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | zharkent
# Processing Record 7 of Set 6 | tobe
# Processing Record 8 of Set 6 | honningsvag
# Processing Record 9 of Set 6 | amahai
# Processing Record 10 of Set 6 | sao geraldo do araguaia
# Processing Record 11 of Set 6 | hasaki
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | buraydah
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | obo
# Processing Record 16 of Set 6 | vibo valentia
# Processing Record 17 of Set 6 | macusani
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | libertador general san martin
# Processing Record 20 of Set 6 | amapa
# Processing Record 21 of Set 6 | celestun
# Processing Record 22 of Set 6 | rundu
# Processing Record 23 of Set 6 | terrace bay
# Processing Record 24 of Set 6 | mount isa
# Processing Record 25 of Set 6 | litovko
# Processing Record 26 of Set 6 | grand-santi
# Processing Record 27 of Set 6 | eganville
# Processing Record 28 of Set 6 | beeville
# Processing Record 29 of Set 6 | savannah bight
# Processing Record 30 of Set 6 | lompoc
# Processing Record 31 of Set 6 | jodhpur
# Processing Record 32 of Set 6 | saint anthony
# Processing Record 33 of Set 6 | nhulunbuy
# Processing Record 34 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 6 | odessa
# Processing Record 36 of Set 6 | victor harbor
# Processing Record 37 of Set 6 | sawakin
# Processing Record 38 of Set 6 | zapolyarnyy
# Processing Record 39 of Set 6 | faanui
# Processing Record 40 of Set 6 | christchurch
# Processing Record 41 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 42 of Set 6 | dharchula
# Processing Record 43 of Set 6 | iracoubo
# Processing Record 44 of Set 6 | zhezkazgan
# Processing Record 45 of Set 6 | manassas
# Processing Record 46 of Set 6 | la ronge
# Processing Record 47 of Set 6 | aranos
# Processing Record 48 of Set 6 | taoudenni
# Processing Record 49 of Set 6 | mahajanga
# Processing Record 50 of Set 6 | volterra
# Processing Record 1 of Set 7 | isangel
# Processing Record 2 of Set 7 | giresun
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | dossor
# Processing Record 5 of Set 7 | cidreira
# Processing Record 6 of Set 7 | teguldet
# Processing Record 7 of Set 7 | iralaya
# Processing Record 8 of Set 7 | harbour breton
# Processing Record 9 of Set 7 | kurilsk
# Processing Record 10 of Set 7 | santa rosa
# Processing Record 11 of Set 7 | eqbaliyeh
# Processing Record 12 of Set 7 | matagami
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | avarua
# Processing Record 15 of Set 7 | bombay
# Processing Record 16 of Set 7 | kenai
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | hami
# Processing Record 19 of Set 7 | sattahip
# Processing Record 20 of Set 7 | magadan
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | castro
# Processing Record 23 of Set 7 | taksimo
# Processing Record 24 of Set 7 | saint-pierre
# Processing Record 25 of Set 7 | touros
# Processing Record 26 of Set 7 | mayo
# Processing Record 27 of Set 7 | purificacion
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | kloulklubed
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | aksarka
# Processing Record 33 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 7 | semey
# Processing Record 35 of Set 7 | chippewa falls
# Processing Record 36 of Set 7 | zhangzhou
# Processing Record 37 of Set 7 | peniche
# Processing Record 38 of Set 7 | pangody
# Processing Record 39 of Set 7 | yicheng
# Processing Record 40 of Set 7 | srednekolymsk
# Processing Record 41 of Set 7 | hobyo
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 7 | pierre
# Processing Record 45 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 46 of Set 7 | alihe
# Processing Record 47 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 7 | kyabram
# Processing Record 49 of Set 7 | atar
# Processing Record 50 of Set 7 | macas
# Processing Record 1 of Set 8 | ginda
# Processing Record 2 of Set 8 | kindu
# Processing Record 3 of Set 8 | tromso
# Processing Record 4 of Set 8 | port moresby
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 8 | mount gambier
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | birin
# Processing Record 10 of Set 8 | cayenne
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | simbahan
# Processing Record 13 of Set 8 | nemuro
# Processing Record 14 of Set 8 | khuzhir
# Processing Record 15 of Set 8 | verrettes
# Processing Record 16 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 8 | prieska
# Processing Record 18 of Set 8 | nalut
# Processing Record 19 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 8 | bamiantong
# Processing Record 21 of Set 8 | paracuru
# Processing Record 22 of Set 8 | sao jose da coroa grande
# Processing Record 23 of Set 8 | lamar
# Processing Record 24 of Set 8 | san ignacio
# Processing Record 25 of Set 8 | palmer
# Processing Record 26 of Set 8 | chernyshevskiy
# Processing Record 27 of Set 8 | evensk
# Processing Record 28 of Set 8 | tondano
# Processing Record 29 of Set 8 | aklavik
# Processing Record 30 of Set 8 | jumla
# Processing Record 31 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 8 | paamiut
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | ballina
# Processing Record 35 of Set 8 | kirkwall
# Processing Record 36 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 8 | baherden
# Processing Record 38 of Set 8 | tavares
# Processing Record 39 of Set 8 | la ligua
# Processing Record 40 of Set 8 | ojinaga
# Processing Record 41 of Set 8 | port hedland
# Processing Record 42 of Set 8 | ishinomaki
# Processing Record 43 of Set 8 | oinoussai
# City not found. Skipping...
# Processing Record 44 of Set 8 | redmond
# Processing Record 45 of Set 8 | adrar
# Processing Record 46 of Set 8 | buala
# Processing Record 47 of Set 8 | pskov
# Processing Record 48 of Set 8 | contai
# Processing Record 49 of Set 8 | waingapu
# Processing Record 50 of Set 8 | antofagasta
# Processing Record 1 of Set 9 | nefteyugansk
# Processing Record 2 of Set 9 | asilah
# Processing Record 3 of Set 9 | qui nhon
# Processing Record 4 of Set 9 | port-cartier
# Processing Record 5 of Set 9 | tahoua
# Processing Record 6 of Set 9 | bambanglipuro
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | shar
# Processing Record 9 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 10 of Set 9 | la libertad
# Processing Record 11 of Set 9 | rawlins
# Processing Record 12 of Set 9 | lima
# Processing Record 13 of Set 9 | polyarnyy
# Processing Record 14 of Set 9 | sitka
# Processing Record 15 of Set 9 | provideniya
# Processing Record 16 of Set 9 | manggar
# Processing Record 17 of Set 9 | atasu
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | hamilton
# Processing Record 20 of Set 9 | werda
# Processing Record 21 of Set 9 | hirara
# Processing Record 22 of Set 9 | port lincoln
# Processing Record 23 of Set 9 | muisne
# Processing Record 24 of Set 9 | praia da vitoria
# Processing Record 25 of Set 9 | vondrozo
# Processing Record 26 of Set 9 | pafos
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | dunedin
# Processing Record 29 of Set 9 | duma
# Processing Record 30 of Set 9 | ilhabela
# Processing Record 31 of Set 9 | hammerfest
# Processing Record 32 of Set 9 | coahuayana
# Processing Record 33 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 9 | ambon
# Processing Record 35 of Set 9 | lorengau
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | leh
# Processing Record 38 of Set 9 | tomatlan
# Processing Record 39 of Set 9 | houston
# Processing Record 40 of Set 9 | puerto el triunfo
# Processing Record 41 of Set 9 | ibra
# Processing Record 42 of Set 9 | matay
# Processing Record 43 of Set 9 | ostrovnoy
# Processing Record 44 of Set 9 | galle
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | sinnamary
# Processing Record 47 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 9 | pochutla
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 1 of Set 10 | yerofey pavlovich
# Processing Record 2 of Set 10 | romitan
# Processing Record 3 of Set 10 | muros
# Processing Record 4 of Set 10 | da nang
# Processing Record 5 of Set 10 | tautira
# Processing Record 6 of Set 10 | tabas
# Processing Record 7 of Set 10 | coquimbo
# Processing Record 8 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 10 | pisco
# Processing Record 10 of Set 10 | mnogovershinnyy
# Processing Record 11 of Set 10 | pacific grove
# Processing Record 12 of Set 10 | esfahan
# Processing Record 13 of Set 10 | tuktoyaktuk
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 16 of Set 10 | cartagena
# Processing Record 17 of Set 10 | nejdek
# Processing Record 18 of Set 10 | porto novo
# Processing Record 19 of Set 10 | chicama
# Processing Record 20 of Set 10 | cabra
# Processing Record 21 of Set 10 | athabasca
# Processing Record 22 of Set 10 | tieling
# Processing Record 23 of Set 10 | morro bay
# Processing Record 24 of Set 10 | yurginskoye
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | bongandanga
# Processing Record 27 of Set 10 | carupano
# Processing Record 28 of Set 10 | chabua
# Processing Record 29 of Set 10 | matamba
# Processing Record 30 of Set 10 | staryy nadym
# Processing Record 31 of Set 10 | bubaque
# Processing Record 32 of Set 10 | broome
# Processing Record 33 of Set 10 | waddan
# Processing Record 34 of Set 10 | nadym
# Processing Record 35 of Set 10 | ponta delgada
# Processing Record 36 of Set 10 | marsassoum
# Processing Record 37 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 10 | fecamp
# Processing Record 39 of Set 10 | kundian
# Processing Record 40 of Set 10 | nola
# Processing Record 41 of Set 10 | sobolevo
# Processing Record 42 of Set 10 | cascais
# Processing Record 43 of Set 10 | ahipara
# Processing Record 44 of Set 10 | tortoli
# Processing Record 45 of Set 10 | bonavista
# Processing Record 46 of Set 10 | cortez
# Processing Record 47 of Set 10 | america dourada
# Processing Record 48 of Set 10 | narsaq
# Processing Record 49 of Set 10 | luderitz
# Processing Record 50 of Set 10 | pilar
# Processing Record 1 of Set 11 | chitral
# Processing Record 2 of Set 11 | ko samui
# Processing Record 3 of Set 11 | hohhot
# Processing Record 4 of Set 11 | santiago
# Processing Record 5 of Set 11 | pokhara
# Processing Record 6 of Set 11 | coos bay
# Processing Record 7 of Set 11 | viedma
# Processing Record 8 of Set 11 | solnechnyy
# Processing Record 9 of Set 11 | kruisfontein
# Processing Record 10 of Set 11 | kargat
# Processing Record 11 of Set 11 | varzea da palma
# Processing Record 12 of Set 11 | angoram
# Processing Record 13 of Set 11 | hay river
# Processing Record 14 of Set 11 | san francisco
# Processing Record 15 of Set 11 | egvekinot
# Processing Record 16 of Set 11 | knysna
# Processing Record 17 of Set 11 | qiongshan
# Processing Record 18 of Set 11 | pimentel
# Processing Record 19 of Set 11 | balkanabat
# Processing Record 20 of Set 11 | clyde river
# Processing Record 21 of Set 11 | bang saphan
# Processing Record 22 of Set 11 | miramar
# Processing Record 23 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 24 of Set 11 | hualmay
# Processing Record 25 of Set 11 | santa maria
# Processing Record 26 of Set 11 | sergeyevka
# Processing Record 27 of Set 11 | maltahohe
# Processing Record 28 of Set 11 | riyadh
# Processing Record 29 of Set 11 | murgab
# Processing Record 30 of Set 11 | melito di porto salvo
# Processing Record 31 of Set 11 | olafsvik
# Processing Record 32 of Set 11 | tuatapere
# Processing Record 33 of Set 11 | makuyuni
# Processing Record 34 of Set 11 | cherskiy
# Processing Record 35 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 36 of Set 11 | katsuura
# Processing Record 37 of Set 11 | praia
# Processing Record 38 of Set 11 | bullhead city
# Processing Record 39 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 11 | oruro
# Processing Record 41 of Set 11 | paraiso
# Processing Record 42 of Set 11 | xaxim
# Processing Record 43 of Set 11 | erzin
# Processing Record 44 of Set 11 | sunrise manor
# Processing Record 45 of Set 11 | sauk rapids
# Processing Record 46 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 47 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 11 | karpathos
# Processing Record 49 of Set 11 | tagusao
# Processing Record 50 of Set 11 | basco
# Processing Record 1 of Set 12 | matara
# Processing Record 2 of Set 12 | flinders
# Processing Record 3 of Set 12 | vanimo
# Processing Record 4 of Set 12 | pokrovka
# Processing Record 5 of Set 12 | axim
# Processing Record 6 of Set 12 | barra patuca
# Processing Record 7 of Set 12 | calgary
# Processing Record 8 of Set 12 | iquitos
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | vila franca do campo
# Processing Record 11 of Set 12 | rovaniemi
# Processing Record 12 of Set 12 | ipilan
# Processing Record 13 of Set 12 | zonguldak
# Processing Record 14 of Set 12 | hambantota
# Processing Record 15 of Set 12 | sorland
# Processing Record 16 of Set 12 | mazara del vallo
# Processing Record 17 of Set 12 | richards bay
# Processing Record 18 of Set 12 | songea
# Processing Record 19 of Set 12 | sabang
# Processing Record 20 of Set 12 | moulins
# Processing Record 21 of Set 12 | chone
# Processing Record 22 of Set 12 | piacabucu
# Processing Record 23 of Set 12 | haines junction
# Processing Record 24 of Set 12 | kurtalan
# Processing Record 25 of Set 12 | poum
# Processing Record 26 of Set 12 | guangzhou
# Processing Record 27 of Set 12 | langenburg
# Processing Record 28 of Set 12 | maniitsoq
# Processing Record 29 of Set 12 | fortuna
# Processing Record 30 of Set 12 | peleduy
# Processing Record 31 of Set 12 | palana
# Processing Record 32 of Set 12 | lipin bor
# Processing Record 33 of Set 12 | belmonte
# Processing Record 34 of Set 12 | del rio
# Processing Record 35 of Set 12 | monrovia
# Processing Record 36 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 12 | jian
# Processing Record 38 of Set 12 | tutoia
# Processing Record 39 of Set 12 | savalou
# Processing Record 40 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 41 of Set 12 | panguna
# Processing Record 42 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 12 | polessk
# Processing Record 44 of Set 12 | bluefield
# Processing Record 45 of Set 12 | xuddur
# Processing Record 46 of Set 12 | armidale
# Processing Record 47 of Set 12 | sayat
# Processing Record 48 of Set 12 | kedainiai
# Processing Record 49 of Set 12 | pangani
# Processing Record 50 of Set 12 | taruma
# Processing Record 1 of Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 2 of Set 13 | velyka bahachka
# Processing Record 3 of Set 13 | rio gallegos
# Processing Record 4 of Set 13 | kemijarvi
# Processing Record 5 of Set 13 | talnakh
# Processing Record 6 of Set 13 | prince rupert
# Processing Record 7 of Set 13 | abha
# Processing Record 8 of Set 13 | maceio
# Processing Record 9 of Set 13 | porto walter
# Processing Record 10 of Set 13 | cap malheureux
# Processing Record 11 of Set 13 | podporozhye
# Processing Record 12 of Set 13 | nkhotakota
# Processing Record 13 of Set 13 | morondava
# Processing Record 14 of Set 13 | plettenberg bay
# Processing Record 15 of Set 13 | springdale
# Processing Record 16 of Set 13 | si sa ket
# Processing Record 17 of Set 13 | englehart
# Processing Record 18 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 13 | laguna
# Processing Record 20 of Set 13 | ayorou
# Processing Record 21 of Set 13 | dovers
# Processing Record 22 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 13 | manuk mangkaw
# Processing Record 24 of Set 13 | gamba
# Processing Record 25 of Set 13 | beira
# Processing Record 26 of Set 13 | kozhva
# Processing Record 27 of Set 13 | zheshart
# Processing Record 28 of Set 13 | pauini
# Processing Record 29 of Set 13 | biltine
# Processing Record 30 of Set 13 | vung tau
# Processing Record 31 of Set 13 | waiouru
# Processing Record 32 of Set 13 | amarpur
# Processing Record 33 of Set 13 | sakaiminato
# Processing Record 34 of Set 13 | ahuimanu
# Processing Record 35 of Set 13 | talakan
# Processing Record 36 of Set 13 | rustenburg
# Processing Record 37 of Set 13 | ranong
# Processing Record 38 of Set 13 | jizan
# Processing Record 39 of Set 13 | calvinia
# Processing Record 40 of Set 13 | tucuman
# Processing Record 41 of Set 13 | springfield
# Processing Record 42 of Set 13 | la crosse
# Processing Record 43 of Set 13 | baker city
# Processing Record 44 of Set 13 | makung
# City not found. Skipping...
# Processing Record 45 of Set 13 | warmbad
# Processing Record 46 of Set 13 | denpasar
# Processing Record 47 of Set 13 | kijang
# Processing Record 48 of Set 13 | barnstead
# Processing Record 49 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 13 | port macquarie
# Processing Record 1 of Set 14 | izumo
# Processing Record 2 of Set 14 | imeni poliny osipenko
# Processing Record 3 of Set 14 | san rafael
# Processing Record 4 of Set 14 | rezekne
# Processing Record 5 of Set 14 | challapata
# Processing Record 6 of Set 14 | sistranda
# Processing Record 7 of Set 14 | deputatskiy
# Processing Record 8 of Set 14 | yar-sale
# Processing Record 9 of Set 14 | marsa matruh
# Processing Record 10 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 14 | burica
# City not found. Skipping...
# Processing Record 12 of Set 14 | lang son
# Processing Record 13 of Set 14 | uige
# Processing Record 14 of Set 14 | husavik
# Processing Record 15 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 14 | bandarbeyla
# Processing Record 17 of Set 14 | jiaozuo
# Processing Record 18 of Set 14 | tarauaca
# Processing Record 19 of Set 14 | ellensburg
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | kirakira
# Processing Record 22 of Set 14 | vardo
# Processing Record 23 of Set 14 | maarianhamina
# Processing Record 24 of Set 14 | mogwase
# Processing Record 25 of Set 14 | ribeira brava
# Processing Record 26 of Set 14 | salinopolis
# Processing Record 27 of Set 14 | humberto de campos
# Processing Record 28 of Set 14 | ngunguru
# Processing Record 29 of Set 14 | sabinas
# Processing Record 30 of Set 14 | manaus
# Processing Record 31 of Set 14 | lingyuan
# Processing Record 32 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 33 of Set 14 | lethem
# Processing Record 34 of Set 14 | tessalit
# Processing Record 35 of Set 14 | ormara
# Processing Record 36 of Set 14 | miri
# Processing Record 37 of Set 14 | general pico
# Processing Record 38 of Set 14 | oistins
# Processing Record 39 of Set 14 | mackay
# Processing Record 40 of Set 14 | sao felix do xingu
# Processing Record 41 of Set 14 | langsa
# Processing Record 42 of Set 14 | vostok
# Processing Record 43 of Set 14 | larap
# Processing Record 44 of Set 14 | tual
# Processing Record 45 of Set 14 | alice springs
# Processing Record 46 of Set 14 | ostersund
# Processing Record 47 of Set 14 | vezirkopru
# Processing Record 48 of Set 14 | klyuchi
# Processing Record 49 of Set 14 | tanout
# Processing Record 50 of Set 14 | kavaratti
# Processing Record 1 of Set 15 | preobrazheniye
# Processing Record 2 of Set 15 | bridlington
# Processing Record 3 of Set 15 | bose
# Processing Record 4 of Set 15 | ambulu
# Processing Record 5 of Set 15 | perth
# Processing Record 6 of Set 15 | carahue
# Processing Record 7 of Set 15 | lakselv
# Processing Record 8 of Set 15 | namatanai
# Processing Record 9 of Set 15 | mehamn
# Processing Record 10 of Set 15 | marsh harbour
# Processing Record 11 of Set 15 | megali panayia
# Processing Record 12 of Set 15 | gaspe
# Processing Record 13 of Set 15 | akom
# Processing Record 14 of Set 15 | rapid valley
# Processing Record 15 of Set 15 | pak phanang
# Processing Record 16 of Set 15 | harper
# Processing Record 17 of Set 15 | madukkur
# Processing Record 18 of Set 15 | zurrieq
# Processing Record 19 of Set 15 | lodwar
# Processing Record 20 of Set 15 | liverpool
# Processing Record 21 of Set 15 | pedernales
# Processing Record 22 of Set 15 | kidero
# Processing Record 23 of Set 15 | sao mateus
# Processing Record 24 of Set 15 | broadford
# Processing Record 25 of Set 15 | kampot
# Processing Record 26 of Set 15 | otjimbingwe
# Processing Record 27 of Set 15 | acarau
# Processing Record 28 of Set 15 | sao luiz gonzaga
# Processing Record 29 of Set 15 | kashirskoye
# Processing Record 30 of Set 15 | sao joao da barra
# Processing Record 31 of Set 15 | chirongui
# Processing Record 32 of Set 15 | lagoa
# Processing Record 33 of Set 15 | delijan
# Processing Record 34 of Set 15 | jalu
# Processing Record 35 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 36 of Set 15 | gladstone
# Processing Record 37 of Set 15 | weligama
# Processing Record 38 of Set 15 | kampong thum
# Processing Record 39 of Set 15 | kem
# Processing Record 40 of Set 15 | borlange
# City not found. Skipping...
# Processing Record 41 of Set 15 | oktyabrskoye
# Processing Record 42 of Set 15 | tucurui
# Processing Record 43 of Set 15 | nyurba
# Processing Record 44 of Set 15 | puerto baquerizo moreno
# Processing Record 45 of Set 15 | kollam
# Processing Record 46 of Set 15 | haysyn
# Processing Record 47 of Set 15 | tazmalt
# Processing Record 48 of Set 15 | port-gentil
# Processing Record 49 of Set 15 | lucea
# Processing Record 50 of Set 15 | malanje
# Processing Record 1 of Set 16 | chachapoyas
# Processing Record 2 of Set 16 | along
# Processing Record 3 of Set 16 | truro
# Processing Record 4 of Set 16 | mao
# Processing Record 5 of Set 16 | berlevag
# Processing Record 6 of Set 16 | manaure
# Processing Record 7 of Set 16 | ukiah
# Processing Record 8 of Set 16 | marau
# Processing Record 9 of Set 16 | kenscoff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 700

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     26.11        93         100
# 1          Hobart      AU -42.8794  147.3294     79.27        82          75
# 2         Rikitea      PF -23.1203 -134.9692     77.43        76         100
# 3       Busselton      AU -33.6500  115.3333     82.22        35           0
# 4       Jamestown      US  42.0970  -79.2353     41.02        74         100
# 5    Longyearbyen      SJ  78.2186   15.6401     30.04        80          75
# 6   Santa Rosalia      MX  27.3167 -112.2833     59.41        79          46
# 7       Cape Town      ZA -33.9258   18.4232     79.11        56           0
# 8       Peterhead      GB  57.5058   -1.7981     34.20        77          75
# 9   Pangkalanbuun      ID  -2.6833  111.6167     91.83        43         100
#
#    Wind Speed Current Description
# 0       27.63                snow
# 1       19.57       broken clouds
# 2        9.86          light rain
# 3        3.96           clear sky
# 4        5.75                mist
# 5       28.77       broken clouds
# 6       10.51    scattered clouds
# 7        5.01           clear sky
# 8       16.91       broken clouds
# 9        6.60     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reordered_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=reordered_city_data_df)
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     26.11        93         100
# 1          Hobart      AU -42.8794  147.3294     79.27        82          75
# 2         Rikitea      PF -23.1203 -134.9692     77.43        76         100
# 3       Busselton      AU -33.6500  115.3333     82.22        35           0
# 4       Jamestown      US  42.0970  -79.2353     41.02        74         100
# 5    Longyearbyen      SJ  78.2186   15.6401     30.04        80          75
# 6   Santa Rosalia      MX  27.3167 -112.2833     59.41        79          46
# 7       Cape Town      ZA -33.9258   18.4232     79.11        56           0
# 8       Peterhead      GB  57.5058   -1.7981     34.20        77          75
# 9   Pangkalanbuun      ID  -2.6833  111.6167     91.83        43         100
#
#    Wind Speed Current Description
# 0       27.63                snow
# 1       19.57       broken clouds
# 2        9.86          light rain
# 3        3.96           clear sky
# 4        5.75                mist
# 5       28.77       broken clouds
# 6       10.51    scattered clouds
# 7        5.01           clear sky
# 8       16.91       broken clouds
# 9        6.60     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
